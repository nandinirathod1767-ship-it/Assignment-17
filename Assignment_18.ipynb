# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinirathod1767-ship-it/Assignment-17/blob/main/Assignment_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b05ffb4-9319-4b3f-a758-e0d0b8f0b676" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b05ffb4-9319-4b3f-a758-e0d0b8f0b676">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath='/content/ford_car_dataset.csv'  # Load the Ford Car Dataset
df=pd.read_csv(filepath)     # Change the file path if needed

# %%
print("First 10 rows")
df.head(10)
# Out:
# First 10 rows
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
print("Last 5 rows")
df.tail()
# Out:
# Last 5 rows
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
print("Shape of dataset")
df.shape
# Out:
# Shape of dataset
# (17966, 9)

# %%
print("display all columns datatype")
df.dtypes
# Out:
# display all columns datatype
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
print("missing value each column")
df.isnull()
# Out:
# missing value each column
#        model   year  price  transmission  mileage  fuelType    tax    mpg  \
# 0      False  False  False         False    False     False  False  False
# 1      False  False  False         False    False     False  False  False
# 2      False  False  False         False    False     False  False  False
# 3      False  False  False         False    False     False  False  False
# 4      False  False  False         False    False     False  False  False
# ...      ...    ...    ...           ...      ...       ...    ...    ...
# 17961  False  False  False         False    False     False  False  False
# 17962  False  False  False         False    False     False  False  False
# 17963  False  False  False         False    False     False  False  False
# 17964  False  False  False         False    False     False  False  False
# 17965  False  False  False         False    False     False  False  False
#
#        engineSize
# 0           False
# ...

# %%
# Check the number of duplicate rows
print("Duplicate Rows:")
df.duplicated()
# Out:
# Duplicate Rows:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17961    False
# 17962    False
# 17963    False
# 17964    False
# 17965    False
# Length: 17966, dtype: bool

# %%
# Verify that duplicates are removed
print("Duplicate Rows After Removal:")
df.duplicated().sum()
# Out:
# Duplicate Rows After Removal:
# np.int64(154)

# %%
# statistical summary of all numeric columns
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
# Minimum values
print("\nMinimum Values:")
print(df[['price', 'mileage', 'year']].min())
# Out:
# Minimum Values:
# price       495
# mileage       1
# year       1996
# dtype: int64

# %%
# Maximum values
print("\nMaximum Values:")
print(df[['price', 'mileage', 'year']].max())
# Out:
# Maximum Values:
# price       54995
# mileage    177644
# year         2060
# dtype: int64

# %%
# Mean values
print("\nMean Values:")
print(df[['price', 'mileage', 'year']].mean())
# Out:
# Mean Values:
# price      12279.534844
# mileage    23362.608761
# year        2016.866470
# dtype: float64

# %%
# Median values
print("\nMedian Values:")
print(df[['price', 'mileage', 'year']].median())
# Out:
# Median Values:
# price      11291.0
# mileage    18242.5
# year        2017.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['price'].hist(bins=20, edgecolor='black')
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df['mileage'].hist(bins=20, edgecolor='black')
plt.title("Mileage Distribution")
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.show()

# %%
df['year'].hist(bins=20, edgecolor='black')
plt.title("Year Distribution")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()

# %%
df['engineSize'].hist(bins=20, edgecolor='black')
plt.title("Engine Size Distribution")
plt.xlabel("Engine Size")
plt.ylabel("Frequency")
plt.show()

# %%
df['mpg'].hist(bins=20, edgecolor='black')
plt.title("MPG Distribution")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(18,5))

# Model
plt.subplot(1,3,1)
sns.countplot(x='model', data=df)
plt.title("Model")
plt.xticks(rotation=90)

# Transmission
plt.subplot(1,3,2)
sns.countplot(x='transmission', data=df)
plt.title("Transmission")
plt.xticks(rotation=45)

# Fuel Type
plt.subplot(1,3,3)
sns.countplot(x='fuelType', data=df)
plt.title("Fuel Type")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Insights (Comments)
# 1. Count plots show the frequency of each category.
# 2. The category with the highest count is the most common.
# 3. Popular Ford models appear more frequently in the dataset.
# 4. The dominant transmission type reflects customer preference.
# 5. The most common fuel type indicates current market demand.

# %%
# Model
sns.countplot(x='model', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Transmission
sns.countplot(x='transmission', data=df)
plt.show()

# %%
# Fuel Type
sns.countplot(x='fuelType', data=df)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
y = df['price']
print("Independent Features:")
print(X.columns)
# Out:
# Independent Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %%
print("dependent Features:")
print(y.name)
# Out:
# dependent Features:
# price

# %%
# Display categorical columns
print("Before Encoding:")
print(df[['model', 'fuelType']].head())

# One Hot Encoding
df_encoded = pd.get_dummies(df, columns=['model', 'fuelType', 'transmission'],
                            drop_first=True)

# Display encoded columns
print("\nAfter Encoding:")
print(df_encoded.head())
# Out:
# Before Encoding:
#      model fuelType
# 0   Fiesta   Petrol
# 1    Focus   Petrol
# 2    Focus   Petrol
# 3   Fiesta   Petrol
# 4   Fiesta   Petrol
#
# After Encoding:
#    year  price  mileage  tax   mpg  engineSize  model_ C-MAX  model_ EcoSport  \
# 0  2017  12000    15944  150  57.7         1.0         False            False
# 1  2018  14000     9083  150  57.7         1.0         False            False
# 2  2017  13000    12456  150  57.7         1.0         False            False
# 3  2019  17500    10460  145  40.3         1.5         False            False
# 4  2019  16500     1482  145  48.7         1.0         False            False
#
#    model_ Edge  model_ Escort  ...  model_ Tourneo Connect  \
# 0        False          False  ...                   False
# 1        False          False  ...                   False
# 2        False          False  ...                   False
# 3        False          False  ...                   False
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select numeric independent features
X = df[['year', 'mileage', 'tax', 'mpg', 'engineSize']]

# Apply Standard Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Display first 5 rows
print(X_scaled.head())
# Out:
#        year   mileage       tax       mpg  engineSize
# 0  0.065128 -0.380998  0.591358 -0.020442   -0.811386
# 1  0.552866 -0.733359  0.591358 -0.020442   -0.811386
# 2  0.065128 -0.560132  0.591358 -0.020442   -0.811386
# 3  1.040605 -0.662640  0.510727 -1.738890    0.345070
# 4  1.040605 -1.123724  0.510727 -0.909294   -0.811386

# %%
import pandas as pd

filepath='/content/ford_car_dataset.csv'
df=pd.read_csv(filepath)
print(df.isnull().sum())   # Check missing values

df = df.drop_duplicates()  # Remove duplicate rows
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
# Histogram
df[['price', 'mileage', 'year', 'engineSize', 'mpg']].hist(figsize=(10,8))
plt.show()

# %%
# Count Plot - Fuel Type
sns.countplot(x='fuelType', data=df)
plt.show()

# %%
# Count Plot - Transmission
sns.countplot(x='transmission', data=df)
plt.show()

# %%
# Count Plot - Model
sns.countplot(x='model', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
X = df.drop('price', axis=1)
y = df['price']

print(X.columns)
print(y.name)
# Out:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
# price

# %%
df_encoded = pd.get_dummies(
    df,
    columns=['model', 'transmission', 'fuelType'],
    drop_first=True
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numeric_cols = ['year', 'mileage', 'tax', 'mpg', 'engineSize']

df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

print(df_encoded.head())
# Out:
#        year  price   mileage       tax       mpg  engineSize  model_ C-MAX  \
# 0  0.067059  12000 -0.382994  0.591380 -0.020597   -0.810561         False
# 1  0.554393  14000 -0.736317  0.591380 -0.020597   -0.810561         False
# 2  0.067059  13000 -0.562616  0.591380 -0.020597   -0.810561         False
# 3  1.041726  17500 -0.665405  0.510777 -1.737858    0.345325         False
# 4  1.041726  16500 -1.127749  0.510777 -0.908836   -0.810561         False
#
#    model_ EcoSport  model_ Edge  model_ Escort  ...  model_ Tourneo Connect  \
# 0            False        False          False  ...                   False
# 1            False        False          False  ...                   False
# 2            False        False          False  ...                   False
# 3            False        False          False  ...                   False
# 4            False        False          False  ...                   False
#
# ...
